# %%
# %load_ext autoreload
# %autoreload 2
# %env CUDA_VISIBLE_DEVICES=2
# %env TRANSFORMERS_CACHE=/mnt/LLM/hub
# %env HF_HOME=/mnt/LLM/hub
# %env OMP_NUM_THREADS=16

import os
import sys
sys.path.insert(0, '..')

import time
import random
from tqdm.auto import trange, tqdm
import numpy as np
import ipynbname  # pip install ipynbname

import torch
import torch.nn as nn
import torch.nn.functional as F
import transformers

import ipynbname  # pip install ipynbname
import wandb

from src.aq import QuantizedWeight, QuantizedLinear
from src.modelutils import get_model
from src.datautils import get_loaders


torch.set_num_threads(16)
torch.backends.cudnn.allow_tf32 = False
torch.backends.cuda.matmul.allow_tf32 = False
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# wandb.login(relogin=True)
# Out:
# env: CUDA_VISIBLE_DEVICES=2
# env: TRANSFORMERS_CACHE=/mnt/LLM/hub
# env: HF_HOME=/mnt/LLM/hub
# env: OMP_NUM_THREADS=16
# /home/jheuristic/anaconda3/lib/python3.9/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
class args:
    base_model = "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"
    quant_model = "/extra_disk_1/jheuristic/tinyllama-3t-2x8g8/"
    dtype = 'bfloat16'
    model_seqlen = 1024  # can be 2048 for 1.1B, 4096-8192 for larger models
    device_map = 'auto'
    
    dataset = 'pajama'
    nsamples = 256
    seed = 42
    beam_size = 4
    stochastic_rounding_tau = 0.0
    
    code_lr = 1e-2
    code_lr_plateau_scale = 0.5
    code_betas = (0.0, 0.95)
    delta_decay = 1.0
    codebook_lr = 1e-5
    codebook_betas = (0.9, 0.95)
    codebook_grad_accumulation_steps = 8
    
    
    autocast_dtype = torch.bfloat16  # bfloat16 or None (not using grad scaler!)
    training_dtype = torch.float32
    gradient_checkpointing = False
    devices = [device]

# %%
train_data = get_loaders(
    args.dataset,
    nsamples=args.nsamples * 10,
    seed=args.seed,
    model_path=args.base_model,
    seqlen=args.model_seqlen,
)

base_model = get_model(args.base_model, None, args.dtype, args.device_map)
if not args.device_map:
    base_model = base_model.to(device)
    
quantized_model = get_model(args.base_model, args.quant_model, args.dtype, args.device_map)
if not args.device_map:
    quantized_model = quantized_model.to(device)
quantized_model = quantized_model.to(args.training_dtype)
# Out:
# Loading red_pajama from togethercomputer/RedPajama-Data-1T-Sample
# /home/jheuristic/anaconda3/lib/python3.9/site-packages/datasets/load.py:1429: FutureWarning: The repository for togethercomputer/RedPajama-Data-1T-Sample contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/togethercomputer/RedPajama-Data-1T-Sample
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Loaded data from pajama; len(data)=2560 sequences
# Loading pretrained model ...
# Model loaded sucсessfully ...
# Initializing model with random weights...
# Loading quantized model ...
# Model loaded sucсessfully ...

# %%
from src.pv_ops import create_dequantized_model
dequantized_model, master_parameters = create_dequantized_model(
    quantized_model, reuse_non_quantized=True, dequantized_dtype=args.autocast_dtype
)
for param in dequantized_model.parameters():
    param.data = param.data.to(args.autocast_dtype)

# %%
from src.pv_ops import StraightThroughAdamW

optimizer = StraightThroughAdamW(
    named_dequantized_params=dict(dequantized_model.named_parameters()),
    named_master_params=master_parameters,
    update_codes=dict(lr=args.code_lr, betas=args.code_betas),
    max_code_change_per_step=1e-3,
    beam_size=args.beam_size,
    stochastic_rounding_tau=args.stochastic_rounding_tau,
    clamp_value=1e9,
    debias=True,
    dequantized_dtype=torch.float32,
)

# %%
if args.gradient_checkpointing:
    quantized_model.gradient_checkpointing_enable()
    quantized_model.enable_input_require_grads()
    for module in quantized_model.modules():
        if isinstance(module, QuantizedLinear):
            module.use_checkpoint = True
    dequantized_model.gradient_checkpointing_enable()
    dequantized_model.enable_input_require_grads()

# %%
def _run_one_step(args, base_model, dequantized_model, optimizer, train_data, **kwargs):
    optimizer.zero_grad(set_to_none=True)
    with tqdm(train_data, desc="V step") as progress:

        total_loss = 0.0
        for i, batch in enumerate(progress):
            batch = torch.as_tensor(batch, device=device)
            with torch.no_grad():
                teacher_logits = base_model(batch).logits
            student_logits = dequantized_model(batch).logits  # forward accumulates XTX statistics
            loss = kl_div(student_logits, teacher_logits)
            (loss / len(train_data)).backward()  # backward accumulates gradient
            total_loss = loss.item() / (i + 1) + total_loss * i / (i + 1)
            progress.desc = f"V step: accumulating gradients, loss = {total_loss:.9f}"
            del student_logits, teacher_logits, loss
    optimizer.step(**kwargs)
    optimizer.zero_grad(set_to_none=True)  # reset statistics for the next step
    
    return total_loss


def kl_div(student_hiddens, teacher_hiddens):
    C = student_hiddens.shape[-1]  # num classes
    return F.kl_div(
        input=F.log_softmax(student_hiddens.view(-1, C), dim=-1),
        target=F.log_softmax(teacher_hiddens.view(-1, C), dim=-1),
        log_target=True,
        reduction="batchmean",
    )

# %%
eval_data = get_loaders(
    'wikitext2',
    seed=args.seed,
    model_path=args.base_model,
    seqlen=args.model_seqlen,
    eval_mode=True,
)

@torch.inference_mode()
def eval_ppl_naive(model, eval_data):
    eval_inps = [
        eval_data[:, start: start + args.model_seqlen] for start in range(0, eval_data.shape[1], args.model_seqlen)
    ]
    total_tokens = 0
    nlls = []
    for input_ids in tqdm(eval_inps):
        input_ids = input_ids.to(device)
        lm_logits = model(input_ids).logits

        shift_logits = lm_logits[:, :-1, :].contiguous()
        shift_labels = input_ids[:, 1:]
        loss_fct = nn.CrossEntropyLoss()
        loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))
        neg_log_likelihood = loss.float() * args.model_seqlen
        nlls.append(neg_log_likelihood)
        total_tokens += shift_labels.numel()
    ppl = torch.exp(torch.stack(nlls).sum() / total_tokens)
    return ppl
# Out:
# Loaded data from wikitext2; len(data)=1 sequences

# %%
os.environ["WANDB_NOTEBOOK_NAME"] = os.path.join(os.getcwd(), ipynbname.name() + ".ipynb")
wandb.init(
    project="aqml-full-finetuning",
    config = {
        k: v for k, v
        in args.__dict__.items()
        if not k.startswith("__")
    },
    settings=wandb.Settings(code_dir="."),
    name=ipynbname.name(),
)
# Out:
# wandb: Currently logged in as: denismazur8 (routing-experiments). Use `wandb login --relogin` to force relogin
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/jheuristic/AQLM_pv_test_notebook/notebooks/wandb/run-20240505_040334-x2aauofm</code>
# Syncing run <strong><a href='https://wandb.ai/routing-experiments/aqml-full-finetuning/runs/x2aauofm' target="_blank">tinyllama-2x8-vstep</a></strong> to <a href='https://wandb.ai/routing-experiments/aqml-full-finetuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/routing-experiments/aqml-full-finetuning' target="_blank">https://wandb.ai/routing-experiments/aqml-full-finetuning</a>
#  View run at <a href='https://wandb.ai/routing-experiments/aqml-full-finetuning/runs/x2aauofm' target="_blank">https://wandb.ai/routing-experiments/aqml-full-finetuning/runs/x2aauofm</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/routing-experiments/aqml-full-finetuning/runs/x2aauofm?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
POINTER = 0
def next_train_data():
    global POINTER
    batch = []
    for i in range(args.nsamples):
        batch.append(train_data[POINTER % len(train_data)])
        POINTER += 1
    return batch

# %%
# demo: run the algorithm on a fixed training set till it overfits
# TODO train on large corpora, feed next portion of data into each p and v step

last_ppl_eval_score = None
for i in range(100):
    print("STEP", i)
    if i % 5 == 0:
        ppl_eval_score = eval_ppl_naive(dequantized_model, eval_data).item()
        last_ppl_eval_score = ppl_eval_score
        print("wikitext2 ppl (naive)", ppl_eval_score)

    v_step_train_loss = _run_one_step(args, base_model, dequantized_model, optimizer, next_train_data())
    print("v_step_train_loss", v_step_train_loss)
    state = {
        "ppl_eval_score": ppl_eval_score,
        "v_step_train_loss": v_step_train_loss,
        "step": i,
    }
    wandb.log(state, step=i, commit=True)
# Out:
# STEP 0
#   0%|          | 0/334 [00:00<?, ?it/s]
# wikitext2 ppl (naive) 18.942625045776367
# V step:   0%|          | 0/256 [00:00<?, ?it/s]
# model.layers.0.self_attn.q_proj.weight change rate: 0.0
# model.layers.0.self_attn.k_proj.weight change rate: 0.0
# model.layers.0.self_attn.v_proj.weight change rate: 0.0
# model.layers.0.self_attn.o_proj.weight change rate: 0.0
# model.layers.0.mlp.gate_proj.weight change rate: 0.0
# model.layers.0.mlp.up_proj.weight change rate: 0.0
# model.layers.0.mlp.down_proj.weight change rate: 0.0
# model.layers.1.self_attn.q_proj.weight change rate: 0.0
# model.layers.1.self_attn.k_proj.weight change rate: 0.0
# model.layers.1.self_attn.v_proj.weight change rate: 0.0
# model.layers.1.self_attn.o_proj.weight change rate: 0.0
# model.layers.1.mlp.gate_proj.weight change rate: 0.0
# model.layers.1.mlp.up_proj.weight change rate: 0.0
# model.layers.1.mlp.down_proj.weight change rate: 0.0
# model.layers.2.self_attn.q_proj.weight change rate: 0.0
# model.layers.2.self_attn.k_proj.weight change rate: 0.0
# model.layers.2.self_attn.v_proj.weight change rate: 0.0
# model.layers.2.self_attn.o_proj.weight change rate: 0.0
# model.layers.2.mlp.gate_proj.weight change rate: 0.0
# model.layers.2.mlp.up_proj.weight change rate: 0.0
# model.layers.2.mlp.down_proj.weight change rate: 0.0
# model.layers.3.self_attn.q_proj.weight change rate: 0.0
# model.layers.3.self_attn.k_proj.weight change rate: 0.0
# model.layers.3.self_attn.v_proj.weight change rate: 0.0
# model.layers.3.self_attn.o_proj.weight change rate: 0.0
# model.layers.3.mlp.gate_proj.weight change rate: 0.0
# model.layers.3.mlp.up_proj.weight change rate: 0.0
# model.layers.3.mlp.down_proj.weight change rate: 0.0
# model.layers.4.self_attn.q_proj.weight change rate: 0.0
# model.layers.4.self_attn.k_proj.weight change rate: 0.0
# model.layers.4.self_attn.v_proj.weight change rate: 0.0
# model.layers.4.self_attn.o_proj.weight change rate: 0.0
# model.layers.4.mlp.gate_proj.weight change rate: 0.0
# model.layers.4.mlp.up_proj.weight change rate: 0.0
# model.layers.4.mlp.down_proj.weight change rate: 0.0
# model.layers.5.self_attn.q_proj.weight change rate: 0.0
# model.layers.5.self_attn.k_proj.weight change rate: 0.0
# model.layers.5.self_attn.v_proj.weight change rate: 0.0
# model.layers.5.self_attn.o_proj.weight change rate: 0.0
# model.layers.5.mlp.gate_proj.weight change rate: 0.0
# model.layers.5.mlp.up_proj.weight change rate: 0.0
# model.layers.5.mlp.down_proj.weight change rate: 0.0
# model.layers.6.self_attn.q_proj.weight change rate: 0.0
# model.layers.6.self_attn.k_proj.weight change rate: 0.0
# model.layers.6.self_attn.v_proj.weight change rate: 0.0
# model.layers.6.self_attn.o_proj.weight change rate: 0.0
# model.layers.6.mlp.gate_proj.weight change rate: 0.0
# model.layers.6.mlp.up_proj.weight change rate: 0.0
# model.layers.6.mlp.down_proj.weight change rate: 0.0
# model.layers.7.self_attn.q_proj.weight change rate: 0.0
# model.layers.7.self_attn.k_proj.weight change rate: 0.0
# model.layers.7.self_attn.v_proj.weight change rate: 0.0
# model.layers.7.self_attn.o_proj.weight change rate: 0.0
# model.layers.7.mlp.gate_proj.weight change rate: 0.0
# model.layers.7.mlp.up_proj.weight change rate: 0.0
# model.layers.7.mlp.down_proj.weight change rate: 0.0
# model.layers.8.self_attn.q_proj.weight change rate: 0.0
# model.layers.8.self_attn.k_proj.weight change rate: 0.0
# model.layers.8.self_attn.v_proj.weight change rate: 0.0
# model.layers.8.self_attn.o_proj.weight change rate: 0.0
# model.layers.8.mlp.gate_proj.weight change rate: 0.0
# model.layers.8.mlp.up_proj.weight change rate: 0.0
# model.layers.8.mlp.down_proj.weight change rate: 0.0
# model.layers.9.self_attn.q_proj.weight change rate: 0.0
# model.layers.9.self_attn.k_proj.weight change rate: 0.0
# model.layers.9.self_attn.v_proj.weight change rate: 0.0
# model.layers.9.self_attn.o_proj.weight change rate: 0.0
# model.layers.9.mlp.gate_proj.weight change rate: 0.0
# model.layers.9.mlp.up_proj.weight change rate: 0.0
# model.layers.9.mlp.down_proj.weight change rate: 0.0
# model.layers.10.self_attn.q_proj.weight change rate: 0.0
# model.layers.10.self_attn.k_proj.weight change rate: 0.0
# model.layers.10.self_attn.v_proj.weight change rate: 0.0
# model.layers.10.self_attn.o_proj.weight change rate: 0.0
# model.layers.10.mlp.gate_proj.weight change rate: 0.0
# model.layers.10.mlp.up_proj.weight change rate: 0.0
# model.layers.10.mlp.down_proj.weight change rate: 0.0
# model.layers.11.self_attn.q_proj.weight change rate: 0.0
# model.layers.11.self_attn.k_proj.weight change rate: 0.0
# model.layers.11.self_attn.v_proj.weight change rate: 0.0
# model.layers.11.self_attn.o_proj.weight change rate: 0.0
# model.layers.11.mlp.gate_proj.weight change rate: 0.0
# model.layers.11.mlp.up_proj.weight change rate: 0.0
# model.layers.11.mlp.down_proj.weight change rate: 0.0
# model.layers.12.self_attn.q_proj.weight change rate: 0.0
# model.layers.12.self_attn.k_proj.weight change rate: 0.0
# model.layers.12.self_attn.v_proj.weight change rate: 0.0
# model.layers.12.self_attn.o_proj.weight change rate: 0.0
# model.layers.12.mlp.gate_proj.weight change rate: 0.0
# model.layers.12.mlp.up_proj.weight change rate: 0.0
# model.layers.12.mlp.down_proj.weight change rate: 0.0
# model.layers.13.self_attn.q_proj.weight change rate: 0.0
# model.layers.13.self_attn.k_proj.weight change rate: 0.0
# model.layers.13.self_attn.v_proj.weight change rate: 0.0
# model.layers.13.self_attn.o_proj.weight change rate: 0.0
# model.layers.13.mlp.gate_proj.weight change rate: 0.0
# model.layers.13.mlp.up_proj.weight change rate: 0.0
# model.layers.13.mlp.down_proj.weight change rate: 0.0
# model.layers.14.self_attn.q_proj.weight change rate: 0.0
# model.layers.14.self_attn.k_proj.weight change rate: 0.0
# model.layers.14.self_attn.v_proj.weight change rate: 0.0
# model.layers.14.self_attn.o_proj.weight change rate: 0.0
# model.layers.14.mlp.gate_proj.weight change rate: 0.0
# model.layers.14.mlp.up_proj.weight change rate: 0.0
# model.layers.14.mlp.down_proj.weight change rate: 0.0
# model.layers.15.self_attn.q_proj.weight change rate: 0.0
# model.layers.15.self_attn.k_proj.weight change rate: 0.0
# model.layers.15.self_attn.v_proj.weight change rate: 0.0
# model.layers.15.self_attn.o_proj.weight change rate: 0.0
# model.layers.15.mlp.gate_proj.weight change rate: 0.0
# model.layers.15.mlp.up_proj.weight change rate: 0.0
# model.layers.15.mlp.down_proj.weight change rate: 0.0
# model.layers.16.self_attn.q_proj.weight change rate: 0.0
# model.layers.16.self_attn.k_proj.weight change rate: 0.0
# model.layers.16.self_attn.v_proj.weight change rate: 0.0
# model.layers.16.self_attn.o_proj.weight change rate: 0.0
# model.layers.16.mlp.gate_proj.weight change rate: 0.0
# model.layers.16.mlp.up_proj.weight change rate: 0.0
# model.layers.16.mlp.down_proj.weight change rate: 0.0
# model.layers.17.self_attn.q_proj.weight change rate: 0.0
# model.layers.17.self_attn.k_proj.weight change rate: 0.0
# model.layers.17.self_attn.v_proj.weight change rate: 0.0
# model.layers.17.self_attn.o_proj.weight change rate: 0.0
# model.layers.17.mlp.gate_proj.weight change rate: 0.0
# model.layers.17.mlp.up_proj.weight change rate: 0.0
# model.layers.17.mlp.down_proj.weight change rate: 0.0
# model.layers.18.self_attn.q_proj.weight change rate: 0.0
# model.layers.18.self_attn.k_proj.weight change rate: 0.0
# model.layers.18.self_attn.v_proj.weight change rate: 0.0
# model.layers.18.self_attn.o_proj.weight change rate: 0.0
# model.layers.18.mlp.gate_proj.weight change rate: 0.0
# model.layers.18.mlp.up_proj.weight change rate: 0.0
# model.layers.18.mlp.down_proj.weight change rate: 0.0
# model.layers.19.self_attn.q_proj.weight change rate: 0.0
# model.layers.19.self_attn.k_proj.weight change rate: 0.0
# model.layers.19.self_attn.v_proj.weight change rate: 0.0
# model.layers.19.self_attn.o_proj.weight change rate: 0.0
# model.layers.19.mlp.gate_proj.weight change rate: 0.0
# model.layers.19.mlp.up_proj.weight change rate: 0.0
# model.layers.19.mlp.down_proj.weight change rate: 0.0
# model.layers.20.self_attn.q_proj.weight change rate: 0.0
# model.layers.20.self_attn.k_proj.weight change rate: 0.0
# model.layers.20.self_attn.v_proj.weight change rate: 0.0
# model.layers.20.self_attn.o_proj.weight change rate: 0.0
# model.layers.20.mlp.gate_proj.weight change rate: 0.0
# model.layers.20.mlp.up_proj.weight change rate: 0.0
# model.layers.20.mlp.down_proj.weight change rate: 0.0
# model.layers.21.self_attn.q_proj.weight change rate: 0.0
# model.layers.21.self_attn.k_proj.weight change rate: 0.0
# model.layers.21.self_attn.v_proj.weight change rate: 0.0
# model.layers.21.self_attn.o_proj.weight change rate: 0.0
# model.layers.21.mlp.gate_proj.weight change rate: 0.0
# model.layers.21.mlp.up_proj.weight change rate: 0.0
# model.layers.21.mlp.down_proj.weight change rate: 0.0
# v_step_train_loss 0.6543448845623064
# STEP 1
# V step:   0%|          | 0/256 [00:00<?, ?it/s]
# model.layers.0.self_attn.q_proj.weight change rate: 0.0
# model.layers.0.self_attn.k_proj.weight change rate: 0.0
# model.layers.0.self_attn.v_proj.weight change rate: 0.0
# model.layers.0.self_attn.o_proj.weight change rate: 0.0
# model.layers.0.mlp.gate_proj.weight change rate: 0.0
# model.layers.0.mlp.up_proj.weight change rate: 0.0
# model.layers.0.mlp.down_proj.weight change rate: 0.0
# model.layers.1.self_attn.q_proj.weight change rate: 0.0
# model.layers.1.self_attn.k_proj.weight change rate: 0.0
# model.layers.1.self_attn.v_proj.weight change rate: 0.0
# model.layers.1.self_attn.o_proj.weight change rate: 0.0
# model.layers.1.mlp.gate_proj.weight change rate: 0.0
# model.layers.1.mlp.up_proj.weight change rate: 0.0
# model.layers.1.mlp.down_proj.weight change rate: 0.0
# model.layers.2.self_attn.q_proj.weight change rate: 0.0
# model.layers.2.self_attn.k_proj.weight change rate: 0.0
# model.layers.2.self_attn.v_proj.weight change rate: 0.0
# model.layers.2.self_attn.o_proj.weight change rate: 0.0
# model.layers.2.mlp.gate_proj.weight change rate: 0.0
# model.layers.2.mlp.up_proj.weight change rate: 0.0
# model.layers.2.mlp.down_proj.weight change rate: 0.0
# model.layers.3.self_attn.q_proj.weight change rate: 0.0
# model.layers.3.self_attn.k_proj.weight change rate: 0.0
# model.layers.3.self_attn.v_proj.weight change rate: 0.0
# model.layers.3.self_attn.o_proj.weight change rate: 0.0
# model.layers.3.mlp.gate_proj.weight change rate: 0.0
# model.layers.3.mlp.up_proj.weight change rate: 0.0
# model.layers.3.mlp.down_proj.weight change rate: 0.0
# model.layers.4.self_attn.q_proj.weight change rate: 0.0
# model.layers.4.self_attn.k_proj.weight change rate: 0.0
# model.layers.4.self_attn.v_proj.weight change rate: 0.0
# model.layers.4.self_attn.o_proj.weight change rate: 0.0
# model.layers.4.mlp.gate_proj.weight change rate: 0.0
# model.layers.4.mlp.up_proj.weight change rate: 0.0
# model.layers.4.mlp.down_proj.weight change rate: 0.0
# model.layers.5.self_attn.q_proj.weight change rate: 0.0
# model.layers.5.self_attn.k_proj.weight change rate: 0.0
# model.layers.5.self_attn.v_proj.weight change rate: 0.0
# model.layers.5.self_attn.o_proj.weight change rate: 0.0
# model.layers.5.mlp.gate_proj.weight change rate: 0.0
# model.layers.5.mlp.up_proj.weight change rate: 0.0
# model.layers.5.mlp.down_proj.weight change rate: 0.0
# model.layers.6.self_attn.q_proj.weight change rate: 0.0
# model.layers.6.self_attn.k_proj.weight change rate: 0.0
# model.layers.6.self_attn.v_proj.weight change rate: 0.0
# model.layers.6.self_attn.o_proj.weight change rate: 0.0
# model.layers.6.mlp.gate_proj.weight change rate: 0.0
# model.layers.6.mlp.up_proj.weight change rate: 0.0
# model.layers.6.mlp.down_proj.weight change rate: 0.0
# model.layers.7.self_attn.q_proj.weight change rate: 0.0
# model.layers.7.self_attn.k_proj.weight change rate: 0.0
# model.layers.7.self_attn.v_proj.weight change rate: 0.0
# model.layers.7.self_attn.o_proj.weight change rate: 0.0
# model.layers.7.mlp.gate_proj.weight change rate: 0.0
# model.layers.7.mlp.up_proj.weight change rate: 0.0
# model.layers.7.mlp.down_proj.weight change rate: 0.0
# model.layers.8.self_attn.q_proj.weight change rate: 0.0
# model.layers.8.self_attn.k_proj.weight change rate: 0.0
# model.layers.8.self_attn.v_proj.weight change rate: 0.0
# model.layers.8.self_attn.o_proj.weight change rate: 0.0
# model.layers.8.mlp.gate_proj.weight change rate: 0.0
# model.layers.8.mlp.up_proj.weight change rate: 0.0
# model.layers.8.mlp.down_proj.weight change rate: 0.0
# model.layers.9.self_attn.q_proj.weight change rate: 0.0
# model.layers.9.self_attn.k_proj.weight change rate: 0.0
# model.layers.9.self_attn.v_proj.weight change rate: 0.0
# model.layers.9.self_attn.o_proj.weight change rate: 0.0
# model.layers.9.mlp.gate_proj.weight change rate: 0.0
# model.layers.9.mlp.up_proj.weight change rate: 0.0
# model.layers.9.mlp.down_proj.weight change rate: 0.0
# model.layers.10.self_attn.q_proj.weight change rate: 0.0
# model.layers.10.self_attn.k_proj.weight change rate: 0.0
# model.layers.10.self_attn.v_proj.weight change rate: 0.0
# model.layers.10.self_attn.o_proj.weight change rate: 0.0
# model.layers.10.mlp.gate_proj.weight change rate: 0.0
# model.layers.10.mlp.up_proj.weight change rate: 0.0
# model.layers.10.mlp.down_proj.weight change rate: 0.0
# model.layers.11.self_attn.q_proj.weight change rate: 0.0
# model.layers.11.self_attn.k_proj.weight change rate: 0.0
# model.layers.11.self_attn.v_proj.weight change rate: 0.0
# model.layers.11.self_attn.o_proj.weight change rate: 0.0
# model.layers.11.mlp.gate_proj.weight change rate: 0.0
# model.layers.11.mlp.up_proj.weight change rate: 0.0
# model.layers.11.mlp.down_proj.weight change rate: 0.0
# model.layers.12.self_attn.q_proj.weight change rate: 0.0
# model.layers.12.self_attn.k_proj.weight change rate: 0.0
# model.layers.12.self_attn.v_proj.weight change rate: 0.0
# model.layers.12.self_attn.o_proj.weight change rate: 0.0
# model.layers.12.mlp.gate_proj.weight change rate: 0.0
# model.layers.12.mlp.up_proj.weight change rate: 0.0
# model.layers.12.mlp.down_proj.weight change rate: 0.0
# model.layers.13.self_attn.q_proj.weight change rate: 0.0
# model.layers.13.self_attn.k_proj.weight change rate: 0.0
# model.layers.13.self_attn.v_proj.weight change rate: 0.0
# model.layers.13.self_attn.o_proj.weight change rate: 0.0
# model.layers.13.mlp.gate_proj.weight change rate: 0.0
# model.layers.13.mlp.up_proj.weight change rate: 0.0
# model.layers.13.mlp.down_proj.weight change rate: 0.0
# model.layers.14.self_attn.q_proj.weight change rate: 0.0
# model.layers.14.self_attn.k_proj.weight change rate: 0.0
# model.layers.14.self_attn.v_proj.weight change rate: 0.0
# model.layers.14.self_attn.o_proj.weight change rate: 0.0
# model.layers.14.mlp.gate_proj.weight change rate: 0.0
# model.layers.14.mlp.up_proj.weight change rate: 0.0
# model.layers.14.mlp.down_proj.weight change rate: 0.0
# model.layers.15.self_attn.q_proj.weight change rate: 0.0
# model.layers.15.self_attn.k_proj.weight change rate: 0.0
# model.layers.15.self_attn.v_proj.weight change rate: 0.0
# model.layers.15.self_attn.o_proj.weight change rate: 0.0
# model.layers.15.mlp.gate_proj.weight change rate: 0.0
# model.layers.15.mlp.up_proj.weight change rate: 0.0
# model.layers.15.mlp.down_proj.weight change rate: 0.0
# model.layers.16.self_attn.q_proj.weight change rate: 0.0
# model.layers.16.self_attn.k_proj.weight change rate: 0.0
# model.layers.16.self_attn.v_proj.weight change rate: 0.0
# model.layers.16.self_attn.o_proj.weight change rate: 0.0
# model.layers.16.mlp.gate_proj.weight change rate: 0.0
# model.layers.16.mlp.up_proj.weight change rate: 0.0
# model.layers.16.mlp.down_proj.weight change rate: 0.0
# model.layers.17.self_attn.q_proj.weight change rate: 0.0
# model.layers.17.self_attn.k_proj.weight change rate: 0.0
# model.layers.17.self_attn.v_proj.weight change rate: 0.0
# model.layers.17.self_attn.o_proj.weight change rate: 0.0
# model.layers.17.mlp.gate_proj.weight change rate: 0.0
# model.layers.17.mlp.up_proj.weight change rate: 0.0
# model.layers.17.mlp.down_proj.weight change rate: 0.0
# model.layers.18.self_attn.q_proj.weight change rate: 0.0
# model.layers.18.self_attn.k_proj.weight change rate: 0.0
# model.layers.18.self_attn.v_proj.weight change rate: 0.0
# model.layers.18.self_attn.o_proj.weight change rate: 0.0
# model.layers.18.mlp.gate_proj.weight change rate: 0.0
# model.layers.18.mlp.up_proj.weight change rate: 0.0
# model.layers.18.mlp.down_proj.weight change rate: 0.0
# model.layers.19.self_attn.q_proj.weight change rate: 0.0
# model.layers.19.self_attn.k_proj.weight change rate: 0.0
# model.layers.19.self_attn.v_proj.weight change rate: 0.0
# model.layers.19.self_attn.o_proj.weight change rate: 0.0
# model.layers.19.mlp.gate_proj.weight change rate: 0.0
# model.layers.19.mlp.up_proj.weight change rate: 0.0
# model.layers.19.mlp.down_proj.weight change rate: 0.0
# model.layers.20.self_attn.q_proj.weight change rate: 0.0
# model.layers.20.self_attn.k_proj.weight change rate: 0.0
# model.layers.20.self_attn.v_proj.weight change rate: 0.0
# model.layers.20.self_attn.o_proj.weight change rate: 0.0
# model.layers.20.mlp.gate_proj.weight change rate: 0.0
# model.layers.20.mlp.up_proj.weight change rate: 0.0
# model.layers.20.mlp.down_proj.weight change rate: 0.0
# model.layers.21.self_attn.q_proj.weight change rate: 0.0
# model.layers.21.self_attn.k_proj.weight change rate: 0.0
# model.layers.21.self_attn.v_proj.weight change rate: 0.0
# model.layers.21.self_attn.o_proj.weight change rate: 0.0
# model.layers.21.mlp.gate_proj.weight change rate: 0.0
# model.layers.21.mlp.up_proj.weight change rate: 0.0
# model.layers.21.mlp.down_proj.weight change rate: 0.0
# v_step_train_loss 0.6559324791305692
# STEP 2
# V step:   0%|          | 0/256 [00:00<?, ?it/s]
# model.layers.0.self_attn.q_proj.weight change rate: 0.0
# model.layers.0.self_attn.k_proj.weight change rate: 0.0
# model.layers.0.self_attn.v_proj.weight change rate: 0.0
# model.layers.0.self_attn.o_proj.weight change rate: 0.0
# model.layers.0.mlp.gate_proj.weight change rate: 0.0
# model.layers.0.mlp.up_proj.weight change rate: 0.0
# model.layers.0.mlp.down_proj.weight change rate: 0.0
# model.layers.1.self_attn.q_proj.weight change rate: 0.0
# model.layers.1.self_attn.k_proj.weight change rate: 0.0
# model.layers.1.self_attn.v_proj.weight change rate: 0.0
# model.layers.1.self_attn.o_proj.weight change rate: 0.0
# model.layers.1.mlp.gate_proj.weight change rate: 0.0
# model.layers.1.mlp.up_proj.weight change rate: 0.0
# model.layers.1.mlp.down_proj.weight change rate: 0.0
# model.layers.2.self_attn.q_proj.weight change rate: 0.0
# model.layers.2.self_attn.k_proj.weight change rate: 0.0
# model.layers.2.self_attn.v_proj.weight change rate: 0.0
# model.layers.2.self_attn.o_proj.weight change rate: 0.0
# model.layers.2.mlp.gate_proj.weight change rate: 0.0
# model.layers.2.mlp.up_proj.weight change rate: 0.0
# model.layers.2.mlp.down_proj.weight change rate: 0.0
# model.layers.3.self_attn.q_proj.weight change rate: 0.0
# model.layers.3.self_attn.k_proj.weight change rate: 0.0
# model.layers.3.self_attn.v_proj.weight change rate: 0.0
# model.layers.3.self_attn.o_proj.weight change rate: 0.0
# model.layers.3.mlp.gate_proj.weight change rate: 0.0
# model.layers.3.mlp.up_proj.weight change rate: 0.0
# model.layers.3.mlp.down_proj.weight change rate: 0.0
# model.layers.4.self_attn.q_proj.weight change rate: 0.0
# model.layers.4.self_attn.k_proj.weight change rate: 0.0
# model.layers.4.self_attn.v_proj.weight change rate: 0.0
# model.layers.4.self_attn.o_proj.weight change rate: 0.0
# model.layers.4.mlp.gate_proj.weight change rate: 0.0
# model.layers.4.mlp.up_proj.weight change rate: 0.0
# model.layers.4.mlp.down_proj.weight change rate: 0.0
# model.layers.5.self_attn.q_proj.weight change rate: 0.0
# model.layers.5.self_attn.k_proj.weight change rate: 0.0
# model.layers.5.self_attn.v_proj.weight change rate: 0.0
# model.layers.5.self_attn.o_proj.weight change rate: 0.0
# model.layers.5.mlp.gate_proj.weight change rate: 0.0
# model.layers.5.mlp.up_proj.weight change rate: 0.0
# model.layers.5.mlp.down_proj.weight change rate: 0.0
# model.layers.6.self_attn.q_proj.weight change rate: 0.0
# model.layers.6.self_attn.k_proj.weight change rate: 0.0
# model.layers.6.self_attn.v_proj.weight change rate: 0.0
# model.layers.6.self_attn.o_proj.weight change rate: 0.0
# model.layers.6.mlp.gate_proj.weight change rate: 0.0
# model.layers.6.mlp.up_proj.weight change rate: 0.0
# model.layers.6.mlp.down_proj.weight change rate: 0.0
# model.layers.7.self_attn.q_proj.weight change rate: 0.0
# model.layers.7.self_attn.k_proj.weight change rate: 0.0
# model.layers.7.self_attn.v_proj.weight change rate: 0.0
# model.layers.7.self_attn.o_proj.weight change rate: 0.0
# model.layers.7.mlp.gate_proj.weight change rate: 0.0
# model.layers.7.mlp.up_proj.weight change rate: 0.0
# model.layers.7.mlp.down_proj.weight change rate: 0.0
# model.layers.8.self_attn.q_proj.weight change rate: 0.0
# model.layers.8.self_attn.k_proj.weight change rate: 0.0
# model.layers.8.self_attn.v_proj.weight change rate: 0.0
# model.layers.8.self_attn.o_proj.weight change rate: 0.0
# model.layers.8.mlp.gate_proj.weight change rate: 0.0
# model.layers.8.mlp.up_proj.weight change rate: 0.0
# model.layers.8.mlp.down_proj.weight change rate: 0.0
# model.layers.9.self_attn.q_proj.weight change rate: 0.0
# model.layers.9.self_attn.k_proj.weight change rate: 0.0
# model.layers.9.self_attn.v_proj.weight change rate: 0.0
# model.layers.9.self_attn.o_proj.weight change rate: 0.0
# model.layers.9.mlp.gate_proj.weight change rate: 0.0
# model.layers.9.mlp.up_proj.weight change rate: 0.0
# model.layers.9.mlp.down_proj.weight change rate: 0.0
# model.layers.10.self_attn.q_proj.weight change rate: 0.0
# model.layers.10.self_attn.k_proj.weight change rate: 0.0
# model.layers.10.self_attn.v_proj.weight change rate: 0.0
# model.layers.10.self_attn.o_proj.weight change rate: 0.0
# model.layers.10.mlp.gate_proj.weight change rate: 0.0
# model.layers.10.mlp.up_proj.weight change rate: 0.0
# model.layers.10.mlp.down_proj.weight change rate: 0.0
# model.layers.11.self_attn.q_proj.weight change rate: 0.0
# model.layers.11.self_attn.k_proj.weight change rate: 0.0
# model.layers.11.self_attn.v_proj.weight change rate: 0.0
# model.layers.11.self_attn.o_proj.weight change rate: 0.0
# model.layers.11.mlp.gate_proj.weight change rate: 0.0
# model.layers.11.mlp.up_proj.weight change rate: 0.0
# model.layers.11.mlp.down_proj.weight change rate: 0.0
# model.layers.12.self_attn.q_proj.weight change rate: 0.0
# model.layers.12.self_attn.k_proj.weight change rate: 0.0
# model.layers.12.self_attn.v_proj.weight change rate: 0.0
# model.layers.12.self_attn.o_proj.weight change rate: 0.0
# model.layers.12.mlp.gate_proj.weight change rate: 0.0
# model.layers.12.mlp.up_proj.weight change rate: 0.0
# model.layers.12.mlp.down_proj.weight change rate: 0.0
# model.layers.13.self_attn.q_proj.weight change rate: 0.0
# model.layers.13.self_attn.k_proj.weight change rate: 0.0
# model.layers.13.self_attn.v_proj.weight change rate: 0.0
# model.layers.13.self_attn.o_proj.weight change rate: 0.0
# model.layers.13.mlp.gate_proj.weight change rate: 0.0
# model.layers.13.mlp.up_proj.weight change rate: 0.0
# model.layers.13.mlp.down_proj.weight change rate: 0.0
# model.layers.14.self_attn.q_proj.weight change rate: 0.0
# model.layers.14.self_attn.k_proj.weight change rate: 0.0
# model.layers.14.self_attn.v_proj.weight change rate: 0.0
# model.layers.14.self_attn.o_proj.weight change rate: 0.0
# model.layers.14.mlp.gate_proj.weight change rate: 0.0
# model.layers.14.mlp.up_proj.weight change rate: 0.0
# model.layers.14.mlp.down_proj.weight change rate: 0.0
# model.layers.15.self_attn.q_proj.weight change rate: 0.0
# model.layers.15.self_attn.k_proj.weight change rate: 0.0
# model.layers.15.self_attn.v_proj.weight change rate: 0.0
# model.layers.15.self_attn.o_proj.weight change rate: 0.0
# model.layers.15.mlp.gate_proj.weight change rate: 0.0
# model.layers.15.mlp.up_proj.weight change rate: 0.0
# model.layers.15.mlp.down_proj.weight change rate: 0.0
# model.layers.16.self_attn.q_proj.weight change rate: 0.0
# model.layers.16.self_attn.k_proj.weight change rate: 0.0
# model.layers.16.self_attn.v_proj.weight change rate: 0.0
# model.layers.16.self_attn.o_proj.weight change rate: 0.0
# model.layers.16.mlp.gate_proj.weight change rate: 0.0
# model.layers.16.mlp.up_proj.weight change rate: 0.0
# model.layers.16.mlp.down_proj.weight change rate: 0.0
# model.layers.17.self_attn.q_proj.weight change rate: 0.0
# model.layers.17.self_attn.k_proj.weight change rate: 0.0
# model.layers.17.self_attn.v_proj.weight change rate: 0.0
# model.layers.17.self_attn.o_proj.weight change rate: 0.0
# model.layers.17.mlp.gate_proj.weight change rate: 0.0
# model.layers.17.mlp.up_proj.weight change rate: 0.0
# model.layers.17.mlp.down_proj.weight change rate: 0.0
# model.layers.18.self_attn.q_proj.weight change rate: 0.0
# model.layers.18.self_attn.k_proj.weight change rate: 0.0
# model.layers.18.self_attn.v_proj.weight change rate: 0.0
# model.layers.18.self_attn.o_proj.weight change rate: 0.0
# model.layers.18.mlp.gate_proj.weight change rate: 0.0
# model.layers.18.mlp.up_proj.weight change rate: 0.0
# model.layers.18.mlp.down_proj.weight change rate: 0.0
# model.layers.19.self_attn.q_proj.weight change rate: 0.0
# model.layers.19.self_attn.k_proj.weight change rate: 0.0
# model.layers.19.self_attn.v_proj.weight change rate: 0.0
# model.layers.19.self_attn.o_proj.weight change rate: 0.0
# model.layers.19.mlp.gate_proj.weight change rate: 0.0
# model.layers.19.mlp.up_proj.weight change rate: 0.0
# model.layers.19.mlp.down_proj.weight change rate: 0.0
# model.layers.20.self_attn.q_proj.weight change rate: 0.0
# model.layers.20.self_attn.k_proj.weight change rate: 0.0
# model.layers.20.self_attn.v_proj.weight change rate: 0.0
# model.layers.20.self_attn.o_proj.weight change rate: 0.0
# model.layers.20.mlp.gate_proj.weight change rate: 0.0
# model.layers.20.mlp.up_proj.weight change rate: 0.0
# model.layers.20.mlp.down_proj.weight change rate: 0.0
# model.layers.21.self_attn.q_proj.weight change rate: 0.0
# model.layers.21.self_attn.k_proj.weight change rate: 0.0
# model.layers.21.self_attn.v_proj.weight change rate: 0.0
# model.layers.21.self_attn.o_proj.weight change rate: 0.0
# model.layers.21.mlp.gate_proj.weight change rate: 0.0
# model.layers.21.mlp.up_proj.weight change rate: 0.0
# model.layers.21.mlp.down_proj.weight change rate: 0.0
# v_step_train_loss 0.6871151126106264
# STEP 3
# V step:   0%|          | 0/256 [00:00<?, ?it/s]
# model.layers.0.self_attn.q_proj.weight change rate: 1.621246337890625e-05
# model.layers.0.self_attn.k_proj.weight change rate: 0.0
# model.layers.0.self_attn.v_proj.weight change rate: 0.0
# model.layers.0.self_attn.o_proj.weight change rate: 0.0
# model.layers.0.mlp.gate_proj.weight change rate: 0.0
# model.layers.0.mlp.up_proj.weight change rate: 0.0
# model.layers.0.mlp.down_proj.weight change rate: 0.0
# model.layers.1.self_attn.q_proj.weight change rate: 0.0
# model.layers.1.self_attn.k_proj.weight change rate: 0.0
# model.layers.1.self_attn.v_proj.weight change rate: 0.0
# model.layers.1.self_attn.o_proj.weight change rate: 0.0
# model.layers.1.mlp.gate_proj.weight change rate: 0.0
# model.layers.1.mlp.up_proj.weight change rate: 0.0
# model.layers.1.mlp.down_proj.weight change rate: 0.0
# model.layers.2.self_attn.q_proj.weight change rate: 0.0
# model.layers.2.self_attn.k_proj.weight change rate: 0.0
# model.layers.2.self_attn.v_proj.weight change rate: 0.0
# model.layers.2.self_attn.o_proj.weight change rate: 0.0
# model.layers.2.mlp.gate_proj.weight change rate: 0.0
# model.layers.2.mlp.up_proj.weight change rate: 0.0
# model.layers.2.mlp.down_proj.weight change rate: 0.0
# model.layers.3.self_attn.q_proj.weight change rate: 0.0
# model.layers.3.self_attn.k_proj.weight change rate: 0.0
# model.layers.3.self_attn.v_proj.weight change rate: 0.0
# model.layers.3.self_attn.o_proj.weight change rate: 0.0
# model.layers.3.mlp.gate_proj.weight change rate: 0.0
# model.layers.3.mlp.up_proj.weight change rate: 0.0
# model.layers.3.mlp.down_proj.weight change rate: 0.0
# model.layers.4.self_attn.q_proj.weight change rate: 0.0
# model.layers.4.self_attn.k_proj.weight change rate: 0.0
# model.layers.4.self_attn.v_proj.weight change rate: 0.0
# model.layers.4.self_attn.o_proj.weight change rate: 0.0
# model.layers.4.mlp.gate_proj.weight change rate: 0.0
# model.layers.4.mlp.up_proj.weight change rate: 0.0
# model.layers.4.mlp.down_proj.weight change rate: 0.0
# model.layers.5.self_attn.q_proj.weight change rate: 0.0
# model.layers.5.self_attn.k_proj.weight change rate: 0.0
# model.layers.5.self_attn.v_proj.weight change rate: 0.0
# model.layers.5.self_attn.o_proj.weight change rate: 0.0
# model.layers.5.mlp.gate_proj.weight change rate: 0.0
# model.layers.5.mlp.up_proj.weight change rate: 0.0
# model.layers.5.mlp.down_proj.weight change rate: 0.0
# model.layers.6.self_attn.q_proj.weight change rate: 0.0
# model.layers.6.self_attn.k_proj.weight change rate: 0.0
# model.layers.6.self_attn.v_proj.weight change rate: 0.0
# model.layers.6.self_attn.o_proj.weight change rate: 0.0
# model.layers.6.mlp.gate_proj.weight change rate: 0.0
# model.layers.6.mlp.up_proj.weight change rate: 0.0
# model.layers.6.mlp.down_proj.weight change rate: 0.0
# model.layers.7.self_attn.q_proj.weight change rate: 0.0
# model.layers.7.self_attn.k_proj.weight change rate: 0.0
# model.layers.7.self_attn.v_proj.weight change rate: 0.0
# model.layers.7.self_attn.o_proj.weight change rate: 0.0
# model.layers.7.mlp.gate_proj.weight change rate: 0.0
# model.layers.7.mlp.up_proj.weight change rate: 0.0
# model.layers.7.mlp.down_proj.weight change rate: 0.0
# model.layers.8.self_attn.q_proj.weight change rate: 0.0
# model.layers.8.self_attn.k_proj.weight change rate: 0.0
# model.layers.8.self_attn.v_proj.weight change rate: 0.0
# model.layers.8.self_attn.o_proj.weight change rate: 0.0
# model.layers.8.mlp.gate_proj.weight change rate: 0.0
# model.layers.8.mlp.up_proj.weight change rate: 0.0
# model.layers.8.mlp.down_proj.weight change rate: 0.0
# model.layers.9.self_attn.q_proj.weight change rate: 0.0
# model.layers.9.self_attn.k_proj.weight change rate: 0.0
# model.layers.9.self_attn.v_proj.weight change rate: 0.0
# model.layers.9.self_attn.o_proj.weight change rate: 0.0
# model.layers.9.mlp.gate_proj.weight change rate: 0.0
# model.layers.9.mlp.up_proj.weight change rate: 0.0
# model.layers.9.mlp.down_proj.weight change rate: 0.0
# model.layers.10.self_attn.q_proj.weight change rate: 0.0
# model.layers.10.self_attn.k_proj.weight change rate: 0.0
# model.layers.10.self_attn.v_proj.weight change rate: 0.0
# model.layers.10.self_attn.o_proj.weight change rate: 0.0
# model.layers.10.mlp.gate_proj.weight change rate: 0.0
# model.layers.10.mlp.up_proj.weight change rate: 0.0
# model.layers.10.mlp.down_proj.weight change rate: 0.0
# model.layers.11.self_attn.q_proj.weight change rate: 0.0
# model.layers.11.self_attn.k_proj.weight change rate: 0.0
# model.layers.11.self_attn.v_proj.weight change rate: 0.0
# model.layers.11.self_attn.o_proj.weight change rate: 0.0
# model.layers.11.mlp.gate_proj.weight change rate: 0.0
# model.layers.11.mlp.up_proj.weight change rate: 0.0
# model.layers.11.mlp.down_proj.weight change rate: 0.0
# model.layers.12.self_attn.q_proj.weight change rate: 0.0
# model.layers.12.self_attn.k_proj.weight change rate: 0.0
# model.layers.12.self_attn.v_proj.weight change rate: 0.0
# model.layers.12.self_attn.o_proj.weight change rate: 0.0
# model.layers.12.mlp.gate_proj.weight change rate: 0.0
# model.layers.12.mlp.up_proj.weight change rate: 0.0
# model.layers.12.mlp.down_proj.weight change rate: 0.0
# model.layers.13.self_attn.q_proj.weight change rate: 0.0
# model.layers.13.self_attn.k_proj.weight change rate: 0.0
# model.layers.13.self_attn.v_proj.weight change rate: 0.0
# model.layers.13.self_attn.o_proj.weight change rate: 0.0
# model.layers.13.mlp.gate_proj.weight change rate: 0.0
# model.layers.13.mlp.up_proj.weight change rate: 0.0
# model.layers.13.mlp.down_proj.weight change rate: 0.0
# model.layers.14.self_attn.q_proj.weight change rate: 0.0
# model.layers.14.self_attn.k_proj.weight change rate: 0.0
# model.layers.14.self_attn.v_proj.weight change rate: 0.0
# model.layers.14.self_attn.o_proj.weight change rate: 0.0
# model.layers.14.mlp.gate_proj.weight change rate: 0.0
# model.layers.14.mlp.up_proj.weight change rate: 0.0
# model.layers.14.mlp.down_proj.weight change rate: 0.0
# model.layers.15.self_attn.q_proj.weight change rate: 0.0
# model.layers.15.self_attn.k_proj.weight change rate: 0.0
# model.layers.15.self_attn.v_proj.weight change rate: 0.0
# model.layers.15.self_attn.o_proj.weight change rate: 0.0
# model.layers.15.mlp.gate_proj.weight change rate: 0.0
# model.layers.15.mlp.up_proj.weight change rate: 0.0
# model.layers.15.mlp.down_proj.weight change rate: 0.0
# model.layers.16.self_attn.q_proj.weight change rate: 0.0
# model.layers.16.self_attn.k_proj.weight change rate: 0.0
# model.layers.16.self_attn.v_proj.weight change rate: 0.0
# model.layers.16.self_attn.o_proj.weight change rate: 0.0
# model.layers.16.mlp.gate_proj.weight change rate: 0.0
# model.layers.16.mlp.up_proj.weight change rate: 0.0
# model.layers.16.mlp.down_proj.weight change rate: 0.0
# model.layers.17.self_attn.q_proj.weight change rate: 0.0
# model.layers.17.self_attn.k_proj.weight change rate: 0.0
# model.layers.17.self_attn.v_proj.weight change rate: 0.0
# model.layers.17.self_attn.o_proj.weight change rate: 0.0
# model.layers.17.mlp.gate_proj.weight change rate: 0.0
# model.layers.17.mlp.up_proj.weight change rate: 0.0
# model.layers.17.mlp.down_proj.weight change rate: 0.0
# model.layers.18.self_attn.q_proj.weight change rate: 0.0
# model.layers.18.self_attn.k_proj.weight change rate: 0.0
# model.layers.18.self_attn.v_proj.weight change rate: 0.0
# model.layers.18.self_attn.o_proj.weight change rate: 0.0
# model.layers.18.mlp.gate_proj.weight change rate: 0.0
# model.layers.18.mlp.up_proj.weight change rate: 0.0
# model.layers.18.mlp.down_proj.weight change rate: 0.0
# model.layers.19.self_attn.q_proj.weight change rate: 0.0
# model.layers.19.self_attn.k_proj.weight change rate: 0.0
# model.layers.19.self_attn.v_proj.weight change rate: 0.0
# model.layers.19.self_attn.o_proj.weight change rate: 0.0
# model.layers.19.mlp.gate_proj.weight change rate: 0.0
# model.layers.19.mlp.up_proj.weight change rate: 0.0
# model.layers.19.mlp.down_proj.weight change rate: 0.0
# model.layers.20.self_attn.q_proj.weight change rate: 0.0
# model.layers.20.self_attn.k_proj.weight change rate: 0.0
# model.layers.20.self_attn.v_proj.weight change rate: 0.0
# model.layers.20.self_attn.o_proj.weight change rate: 0.0
# model.layers.20.mlp.gate_proj.weight change rate: 0.0
# model.layers.20.mlp.up_proj.weight change rate: 0.0
# model.layers.20.mlp.down_proj.weight change rate: 0.0
# model.layers.21.self_attn.q_proj.weight change rate: 0.0
# model.layers.21.self_attn.k_proj.weight change rate: 0.0
# model.layers.21.self_attn.v_proj.weight change rate: 0.0
# model.layers.21.self_attn.o_proj.weight change rate: 0.0
# model.layers.21.mlp.gate_proj.weight change rate: 0.0
# model.layers.21.mlp.up_proj.weight change rate: 0.0
# model.layers.21.mlp.down_proj.weight change rate: 0.0
# v_step_train_loss 0.6821766369102991
# STEP 4
# V step:   0%|          | 0/256 [00:00<?, ?it/s]
# model.layers.0.self_attn.q_proj.weight change rate: 4.38690185546875e-05
# model.layers.0.self_attn.k_proj.weight change rate: 2.288818359375e-05
# model.layers.0.self_attn.v_proj.weight change rate: 0.0
# model.layers.0.self_attn.o_proj.weight change rate: 0.0
# model.layers.0.mlp.gate_proj.weight change rate: 0.0
# model.layers.0.mlp.up_proj.weight change rate: 0.0
# model.layers.0.mlp.down_proj.weight change rate: 0.0
# model.layers.1.self_attn.q_proj.weight change rate: 0.0
# model.layers.1.self_attn.k_proj.weight change rate: 0.0
# model.layers.1.self_attn.v_proj.weight change rate: 0.0
# model.layers.1.self_attn.o_proj.weight change rate: 0.0
# model.layers.1.mlp.gate_proj.weight change rate: 0.0
# model.layers.1.mlp.up_proj.weight change rate: 0.0
# model.layers.1.mlp.down_proj.weight change rate: 0.0
# model.layers.2.self_attn.q_proj.weight change rate: 0.0
# model.layers.2.self_attn.k_proj.weight change rate: 0.0
# model.layers.2.self_attn.v_proj.weight change rate: 0.0
# model.layers.2.self_attn.o_proj.weight change rate: 0.0
# model.layers.2.mlp.gate_proj.weight change rate: 0.0
# model.layers.2.mlp.up_proj.weight change rate: 0.0
# model.layers.2.mlp.down_proj.weight change rate: 0.0
# model.layers.3.self_attn.q_proj.weight change rate: 0.0
# model.layers.3.self_attn.k_proj.weight change rate: 0.0
# model.layers.3.self_attn.v_proj.weight change rate: 0.0
# model.layers.3.self_attn.o_proj.weight change rate: 0.0
# model.layers.3.mlp.gate_proj.weight change rate: 0.0
# model.layers.3.mlp.up_proj.weight change rate: 0.0
# model.layers.3.mlp.down_proj.weight change rate: 0.0
# model.layers.4.self_attn.q_proj.weight change rate: 0.0
# model.layers.4.self_attn.k_proj.weight change rate: 0.0
# model.layers.4.self_attn.v_proj.weight change rate: 0.0
# model.layers.4.self_attn.o_proj.weight change rate: 0.0
# model.layers.4.mlp.gate_proj.weight change rate: 0.0
# model.layers.4.mlp.up_proj.weight change rate: 0.0
# model.layers.4.mlp.down_proj.weight change rate: 0.0
# model.layers.5.self_attn.q_proj.weight change rate: 0.0
# model.layers.5.self_attn.k_proj.weight change rate: 0.0
# model.layers.5.self_attn.v_proj.weight change rate: 0.0
# model.layers.5.self_attn.o_proj.weight change rate: 0.0
# model.layers.5.mlp.gate_proj.weight change rate: 0.0
# model.layers.5.mlp.up_proj.weight change rate: 0.0
# model.layers.5.mlp.down_proj.weight change rate: 0.0
# model.layers.6.self_attn.q_proj.weight change rate: 0.0
# model.layers.6.self_attn.k_proj.weight change rate: 0.0
# model.layers.6.self_attn.v_proj.weight change rate: 0.0
# model.layers.6.self_attn.o_proj.weight change rate: 0.0
# model.layers.6.mlp.gate_proj.weight change rate: 0.0
# model.layers.6.mlp.up_proj.weight change rate: 0.0
# model.layers.6.mlp.down_proj.weight change rate: 0.0
# model.layers.7.self_attn.q_proj.weight change rate: 0.0
# model.layers.7.self_attn.k_proj.weight change rate: 0.0
# model.layers.7.self_attn.v_proj.weight change rate: 0.0
# model.layers.7.self_attn.o_proj.weight change rate: 0.0
# model.layers.7.mlp.gate_proj.weight change rate: 0.0
# model.layers.7.mlp.up_proj.weight change rate: 0.0
# model.layers.7.mlp.down_proj.weight change rate: 0.0
# model.layers.8.self_attn.q_proj.weight change rate: 0.0
# model.layers.8.self_attn.k_proj.weight change rate: 0.0
# model.layers.8.self_attn.v_proj.weight change rate: 0.0
# model.layers.8.self_attn.o_proj.weight change rate: 0.0
# model.layers.8.mlp.gate_proj.weight change rate: 0.0
# model.layers.8.mlp.up_proj.weight change rate: 0.0
# model.layers.8.mlp.down_proj.weight change rate: 0.0
# model.layers.9.self_attn.q_proj.weight change rate: 0.0
# model.layers.9.self_attn.k_proj.weight change rate: 0.0
# model.layers.9.self_attn.v_proj.weight change rate: 0.0
# model.layers.9.self_attn.o_proj.weight change rate: 0.0
# model.layers.9.mlp.gate_proj.weight change rate: 0.0
# model.layers.9.mlp.up_proj.weight change rate: 0.0
# model.layers.9.mlp.down_proj.weight change rate: 0.0
# model.layers.10.self_attn.q_proj.weight change rate: 0.0
# model.layers.10.self_attn.k_proj.weight change rate: 0.0
# model.layers.10.self_attn.v_proj.weight change rate: 0.0
# model.layers.10.self_attn.o_proj.weight change rate: 0.0
# model.layers.10.mlp.gate_proj.weight change rate: 0.0
# model.layers.10.mlp.up_proj.weight change rate: 0.0
# model.layers.10.mlp.down_proj.weight change rate: 0.0
# model.layers.11.self_attn.q_proj.weight change rate: 0.0
# model.layers.11.self_attn.k_proj.weight change rate: 0.0
# model.layers.11.self_attn.v_proj.weight change rate: 0.0
# model.layers.11.self_attn.o_proj.weight change rate: 0.0
# model.layers.11.mlp.gate_proj.weight change rate: 0.0
# model.layers.11.mlp.up_proj.weight change rate: 0.0
# model.layers.11.mlp.down_proj.weight change rate: 0.0
# model.layers.12.self_attn.q_proj.weight change rate: 0.0
# model.layers.12.self_attn.k_proj.weight change rate: 0.0
# model.layers.12.self_attn.v_proj.weight change rate: 0.0
# model.layers.12.self_attn.o_proj.weight change rate: 0.0
# model.layers.12.mlp.gate_proj.weight change rate: 0.0
# model.layers.12.mlp.up_proj.weight change rate: 0.0
# model.layers.12.mlp.down_proj.weight change rate: 0.0
# model.layers.13.self_attn.q_proj.weight change rate: 0.0
# model.layers.13.self_attn.k_proj.weight change rate: 0.0
# model.layers.13.self_attn.v_proj.weight change rate: 0.0
# model.layers.13.self_attn.o_proj.weight change rate: 0.0
# model.layers.13.mlp.gate_proj.weight change rate: 0.0
# model.layers.13.mlp.up_proj.weight change rate: 0.0
# model.layers.13.mlp.down_proj.weight change rate: 0.0
# model.layers.14.self_attn.q_proj.weight change rate: 0.0
# model.layers.14.self_attn.k_proj.weight change rate: 0.0
# model.layers.14.self_attn.v_proj.weight change rate: 0.0
# model.layers.14.self_attn.o_proj.weight change rate: 0.0
# model.layers.14.mlp.gate_proj.weight change rate: 0.0
# model.layers.14.mlp.up_proj.weight change rate: 0.0
# model.layers.14.mlp.down_proj.weight change rate: 0.0
# model.layers.15.self_attn.q_proj.weight change rate: 0.0
# model.layers.15.self_attn.k_proj.weight change rate: 0.0
# model.layers.15.self_attn.v_proj.weight change rate: 0.0
# model.layers.15.self_attn.o_proj.weight change rate: 0.0
# model.layers.15.mlp.gate_proj.weight change rate: 0.0
# model.layers.15.mlp.up_proj.weight change rate: 0.0
# model.layers.15.mlp.down_proj.weight change rate: 0.0
# model.layers.16.self_attn.q_proj.weight change rate: 0.0
# model.layers.16.self_attn.k_proj.weight change rate: 0.0
# model.layers.16.self_attn.v_proj.weight change rate: 0.0
# model.layers.16.self_attn.o_proj.weight change rate: 0.0
# model.layers.16.mlp.gate_proj.weight change rate: 0.0
# model.layers.16.mlp.up_proj.weight change rate: 0.0
# model.layers.16.mlp.down_proj.weight change rate: 0.0
# model.layers.17.self_attn.q_proj.weight change rate: 0.0
# model.layers.17.self_attn.k_proj.weight change rate: 0.0
# model.layers.17.self_attn.v_proj.weight change rate: 0.0
# model.layers.17.self_attn.o_proj.weight change rate: 0.0
# model.layers.17.mlp.gate_proj.weight change rate: 0.0
# model.layers.17.mlp.up_proj.weight change rate: 0.0
# model.layers.17.mlp.down_proj.weight change rate: 0.0
# model.layers.18.self_attn.q_proj.weight change rate: 0.0
# model.layers.18.self_attn.k_proj.weight change rate: 0.0
# model.layers.18.self_attn.v_proj.weight change rate: 0.0
# model.layers.18.self_attn.o_proj.weight change rate: 0.0
# model.layers.18.mlp.gate_proj.weight change rate: 0.0
# model.layers.18.mlp.up_proj.weight change rate: 0.0
# model.layers.18.mlp.down_proj.weight change rate: 0.0
# model.layers.19.self_attn.q_proj.weight change rate: 0.0
# model.layers.19.self_attn.k_proj.weight change rate: 0.0
# model.layers.19.self_attn.v_proj.weight change rate: 0.0
# model.layers.19.self_attn.o_proj.weight change rate: 0.0
# model.layers.19.mlp.gate_proj.weight change rate: 0.0
# model.layers.19.mlp.up_proj.weight change rate: 0.0
# model.layers.19.mlp.down_proj.weight change rate: 0.0
# model.layers.20.self_attn.q_proj.weight change rate: 0.0
# model.layers.20.self_attn.k_proj.weight change rate: 0.0
# model.layers.20.self_attn.v_proj.weight change rate: 0.0
# model.layers.20.self_attn.o_proj.weight change rate: 0.0
# model.layers.20.mlp.gate_proj.weight change rate: 0.0
# model.layers.20.mlp.up_proj.weight change rate: 0.0
# model.layers.20.mlp.down_proj.weight change rate: 0.0
# model.layers.21.self_attn.q_proj.weight change rate: 0.0
# model.layers.21.self_attn.k_proj.weight change rate: 0.0
# model.layers.21.self_attn.v_proj.weight change rate: 0.0
# model.layers.21.self_attn.o_proj.weight change rate: 0.0
# model.layers.21.mlp.gate_proj.weight change rate: 0.0
# model.layers.21.mlp.up_proj.weight change rate: 0.0
# model.layers.21.mlp.down_proj.weight change rate: 0.0
# v_step_train_loss 0.664554816437884
# STEP 5
#   0%|          | 0/334 [00:00<?, ?it/s]
# wikitext2 ppl (naive) 18.94213104248047
# V step:   0%|          | 0/256 [00:00<?, ?it/s]
# model.layers.0.self_attn.q_proj.weight change rate: 0.00017642974853515625
# model.layers.0.self_attn.k_proj.weight change rate: 9.1552734375e-05
# model.layers.0.self_attn.v_proj.weight change rate: 0.0
# model.layers.0.self_attn.o_proj.weight change rate: 0.0
# model.layers.0.mlp.gate_proj.weight change rate: 0.0
# model.layers.0.mlp.up_proj.weight change rate: 0.0
# model.layers.0.mlp.down_proj.weight change rate: 0.0
# model.layers.1.self_attn.q_proj.weight change rate: 0.0
# model.layers.1.self_attn.k_proj.weight change rate: 0.0
# model.layers.1.self_attn.v_proj.weight change rate: 0.0
# model.layers.1.self_attn.o_proj.weight change rate: 0.0
# model.layers.1.mlp.gate_proj.weight change rate: 0.0
# model.layers.1.mlp.up_proj.weight change rate: 0.0
# model.layers.1.mlp.down_proj.weight change rate: 0.0
# model.layers.2.self_attn.q_proj.weight change rate: 0.0
# model.layers.2.self_attn.k_proj.weight change rate: 0.0
# model.layers.2.self_attn.v_proj.weight change rate: 0.0
# model.layers.2.self_attn.o_proj.weight change rate: 0.0
# model.layers.2.mlp.gate_proj.weight change rate: 0.0
# model.layers.2.mlp.up_proj.weight change rate: 0.0
# model.layers.2.mlp.down_proj.weight change rate: 0.0
# model.layers.3.self_attn.q_proj.weight change rate: 1.9073486328125e-06
# model.layers.3.self_attn.k_proj.weight change rate: 0.0
# model.layers.3.self_attn.v_proj.weight change rate: 0.0
# model.layers.3.self_attn.o_proj.weight change rate: 0.0
# model.layers.3.mlp.gate_proj.weight change rate: 0.0
# model.layers.3.mlp.up_proj.weight change rate: 0.0
# model.layers.3.mlp.down_proj.weight change rate: 0.0
# model.layers.4.self_attn.q_proj.weight change rate: 0.0
# model.layers.4.self_attn.k_proj.weight change rate: 0.0
# model.layers.4.self_attn.v_proj.weight change rate: 0.0
# model.layers.4.self_attn.o_proj.weight change rate: 0.0
# model.layers.4.mlp.gate_proj.weight change rate: 0.0
# model.layers.4.mlp.up_proj.weight change rate: 0.0
# model.layers.4.mlp.down_proj.weight change rate: 0.0
# model.layers.5.self_attn.q_proj.weight change rate: 0.0
# model.layers.5.self_attn.k_proj.weight change rate: 0.0
# model.layers.5.self_attn.v_proj.weight change rate: 0.0
# model.layers.5.self_attn.o_proj.weight change rate: 0.0
# model.layers.5.mlp.gate_proj.weight change rate: 0.0
# model.layers.5.mlp.up_proj.weight change rate: 0.0
# model.layers.5.mlp.down_proj.weight change rate: 0.0
# model.layers.6.self_attn.q_proj.weight change rate: 0.0
# model.layers.6.self_attn.k_proj.weight change rate: 0.0
# model.layers.6.self_attn.v_proj.weight change rate: 0.0
# model.layers.6.self_attn.o_proj.weight change rate: 0.0
# model.layers.6.mlp.gate_proj.weight change rate: 0.0
# model.layers.6.mlp.up_proj.weight change rate: 0.0
# model.layers.6.mlp.down_proj.weight change rate: 0.0
# model.layers.7.self_attn.q_proj.weight change rate: 0.0
# model.layers.7.self_attn.k_proj.weight change rate: 0.0
# model.layers.7.self_attn.v_proj.weight change rate: 0.0
# model.layers.7.self_attn.o_proj.weight change rate: 0.0
# model.layers.7.mlp.gate_proj.weight change rate: 0.0
# model.layers.7.mlp.up_proj.weight change rate: 0.0
# model.layers.7.mlp.down_proj.weight change rate: 0.0
# model.layers.8.self_attn.q_proj.weight change rate: 0.0
# model.layers.8.self_attn.k_proj.weight change rate: 0.0
# model.layers.8.self_attn.v_proj.weight change rate: 0.0
# model.layers.8.self_attn.o_proj.weight change rate: 0.0
# model.layers.8.mlp.gate_proj.weight change rate: 0.0
# model.layers.8.mlp.up_proj.weight change rate: 0.0
# model.layers.8.mlp.down_proj.weight change rate: 0.0
# model.layers.9.self_attn.q_proj.weight change rate: 0.0
# model.layers.9.self_attn.k_proj.weight change rate: 0.0
# model.layers.9.self_attn.v_proj.weight change rate: 0.0
# model.layers.9.self_attn.o_proj.weight change rate: 0.0
# model.layers.9.mlp.gate_proj.weight change rate: 0.0
# model.layers.9.mlp.up_proj.weight change rate: 0.0
# model.layers.9.mlp.down_proj.weight change rate: 0.0
# model.layers.10.self_attn.q_proj.weight change rate: 0.0
# model.layers.10.self_attn.k_proj.weight change rate: 0.0
# model.layers.10.self_attn.v_proj.weight change rate: 0.0
# model.layers.10.self_attn.o_proj.weight change rate: 0.0
# model.layers.10.mlp.gate_proj.weight change rate: 0.0
# model.layers.10.mlp.up_proj.weight change rate: 0.0
# model.layers.10.mlp.down_proj.weight change rate: 0.0
# model.layers.11.self_attn.q_proj.weight change rate: 0.0
# model.layers.11.self_attn.k_proj.weight change rate: 0.0
# model.layers.11.self_attn.v_proj.weight change rate: 0.0
# model.layers.11.self_attn.o_proj.weight change rate: 0.0
# model.layers.11.mlp.gate_proj.weight change rate: 0.0
# model.layers.11.mlp.up_proj.weight change rate: 0.0
# model.layers.11.mlp.down_proj.weight change rate: 0.0
# model.layers.12.self_attn.q_proj.weight change rate: 0.0
# model.layers.12.self_attn.k_proj.weight change rate: 0.0
# model.layers.12.self_attn.v_proj.weight change rate: 0.0
# model.layers.12.self_attn.o_proj.weight change rate: 0.0
# model.layers.12.mlp.gate_proj.weight change rate: 0.0
# ...
# model.layers.12.mlp.gate_proj.weight change rate: 0.0005090886843390763
# model.layers.12.mlp.up_proj.weight change rate: 0.0005038868403062224
# model.layers.12.mlp.down_proj.weight change rate: 0.0005049272440373898
# model.layers.13.self_attn.q_proj.weight change rate: 0.0007429122924804688
# model.layers.13.self_attn.k_proj.weight change rate: 0.0005340576171875
# model.layers.13.self_attn.v_proj.weight change rate: 0.00086212158203125
# model.layers.13.self_attn.o_proj.weight change rate: 0.0008497238159179688
# model.layers.13.mlp.gate_proj.weight change rate: 0.00080108642578125
# model.layers.13.mlp.up_proj.weight change rate: 0.0007182034896686673
# model.layers.13.mlp.down_proj.weight change rate: 0.0005080483388155699
# model.layers.14.self_attn.q_proj.weight change rate: 0.000804901123046875
# model.layers.14.self_attn.k_proj.weight change rate: 0.0007476806640625
# model.layers.14.self_attn.v_proj.weight change rate: 0.00052642822265625
# model.layers.14.self_attn.o_proj.weight change rate: 0.0005207061767578125
# model.layers.14.mlp.gate_proj.weight change rate: 0.0005070079350844026
# model.layers.14.mlp.up_proj.weight change rate: 0.0008361123036593199
# model.layers.14.mlp.down_proj.weight change rate: 0.0005045804427936673
# model.layers.15.self_attn.q_proj.weight change rate: 0.0005502700805664062
# model.layers.15.self_attn.k_proj.weight change rate: 0.000701904296875
# model.layers.15.self_attn.v_proj.weight change rate: 0.0007476806640625
# model.layers.15.self_attn.o_proj.weight change rate: 0.0007734298706054688
# model.layers.15.mlp.gate_proj.weight change rate: 0.0005049272440373898
# model.layers.15.mlp.up_proj.weight change rate: 0.0008121837745420635
# model.layers.15.mlp.down_proj.weight change rate: 0.0007899891352280974
# model.layers.16.self_attn.q_proj.weight change rate: 0.0005340576171875
# model.layers.16.self_attn.k_proj.weight change rate: 0.00083160400390625
# model.layers.16.self_attn.v_proj.weight change rate: 0.00052642822265625
# model.layers.16.self_attn.o_proj.weight change rate: 0.0005092620849609375
# model.layers.16.mlp.gate_proj.weight change rate: 0.0007331154774874449
# model.layers.16.mlp.up_proj.weight change rate: 0.000789642333984375
# model.layers.16.mlp.down_proj.weight change rate: 0.0007618991076014936
# model.layers.17.self_attn.q_proj.weight change rate: 0.0005474090576171875
# model.layers.17.self_attn.k_proj.weight change rate: 0.00052642822265625
# model.layers.17.self_attn.v_proj.weight change rate: 0.0006561279296875
# model.layers.17.self_attn.o_proj.weight change rate: 0.000514984130859375
# model.layers.17.mlp.gate_proj.weight change rate: 0.0005070079350844026
# model.layers.17.mlp.up_proj.weight change rate: 0.0007299943827092648
# model.layers.17.mlp.down_proj.weight change rate: 0.0007421320187859237
# model.layers.18.self_attn.q_proj.weight change rate: 0.000537872314453125
# model.layers.18.self_attn.k_proj.weight change rate: 0.00051116943359375
# model.layers.18.self_attn.v_proj.weight change rate: 0.0008697509765625
# model.layers.18.self_attn.o_proj.weight change rate: 0.000514984130859375
# model.layers.18.mlp.gate_proj.weight change rate: 0.0005052739870734513
# model.layers.18.mlp.up_proj.weight change rate: 0.0007861744379624724
# model.layers.18.mlp.down_proj.weight change rate: 0.0007587780128233135
# model.layers.19.self_attn.q_proj.weight change rate: 0.0005559921264648438
# model.layers.19.self_attn.k_proj.weight change rate: 0.00054931640625
# model.layers.19.self_attn.v_proj.weight change rate: 0.0008544921875
# model.layers.19.self_attn.o_proj.weight change rate: 0.0007600784301757812
# model.layers.19.mlp.gate_proj.weight change rate: 0.0005042336415499449
# model.layers.19.mlp.up_proj.weight change rate: 0.0007348494254983962
# model.layers.19.mlp.down_proj.weight change rate: 0.0007462935172952712
# model.layers.20.self_attn.q_proj.weight change rate: 0.0007495880126953125
# model.layers.20.self_attn.k_proj.weight change rate: 0.00054168701171875
# model.layers.20.self_attn.v_proj.weight change rate: 0.000701904296875
# model.layers.20.self_attn.o_proj.weight change rate: 0.000732421875
# model.layers.20.mlp.gate_proj.weight change rate: 0.0005087419413030148
# model.layers.20.mlp.up_proj.weight change rate: 0.0005059675895608962
# model.layers.20.mlp.down_proj.weight change rate: 0.0005045804427936673
# model.layers.21.self_attn.q_proj.weight change rate: 0.0005426406860351562
# model.layers.21.self_attn.k_proj.weight change rate: 0.00070953369140625
# model.layers.21.self_attn.v_proj.weight change rate: 0.00083160400390625
# model.layers.21.self_attn.o_proj.weight change rate: 0.0005140304565429688
# model.layers.21.mlp.gate_proj.weight change rate: 0.0008191195665858686
# model.layers.21.mlp.up_proj.weight change rate: 0.0007299943827092648
# model.layers.21.mlp.down_proj.weight change rate: 0.0008253618143498898
# v_step_train_loss 0.16864341960172166
# STEP 99
# V step:   0%|          | 0/256 [00:00<?, ?it/s]
# model.layers.0.self_attn.q_proj.weight change rate: 0.00075531005859375
# model.layers.0.self_attn.k_proj.weight change rate: 0.0006866455078125
# model.layers.0.self_attn.v_proj.weight change rate: 0.000518798828125
# model.layers.0.self_attn.o_proj.weight change rate: 0.0005779266357421875
# model.layers.0.mlp.gate_proj.weight change rate: 0.0005035400390625
# model.layers.0.mlp.up_proj.weight change rate: 0.0007886019884608686
# model.layers.0.mlp.down_proj.weight change rate: 0.0007136951899155974
# model.layers.1.self_attn.q_proj.weight change rate: 0.0006122589111328125
# model.layers.1.self_attn.k_proj.weight change rate: 0.00064849853515625
# model.layers.1.self_attn.v_proj.weight change rate: 0.0005035400390625
# model.layers.1.self_attn.o_proj.weight change rate: 0.0005130767822265625
# model.layers.1.mlp.gate_proj.weight change rate: 0.0008000460802577436
# model.layers.1.mlp.up_proj.weight change rate: 0.0005000721430405974
# model.layers.1.mlp.down_proj.weight change rate: 0.0007632862543687224
# model.layers.2.self_attn.q_proj.weight change rate: 0.000797271728515625
# model.layers.2.self_attn.k_proj.weight change rate: 0.0006561279296875
# model.layers.2.self_attn.v_proj.weight change rate: 0.000762939453125
# model.layers.2.self_attn.o_proj.weight change rate: 0.0007781982421875
# model.layers.2.mlp.gate_proj.weight change rate: 0.0005021528922952712
# model.layers.2.mlp.up_proj.weight change rate: 0.0005007657455280423
# model.layers.2.mlp.down_proj.weight change rate: 0.0007473339210264385
# model.layers.3.self_attn.q_proj.weight change rate: 0.000820159912109375
# model.layers.3.self_attn.k_proj.weight change rate: 0.00074005126953125
# model.layers.3.self_attn.v_proj.weight change rate: 0.00072479248046875
# model.layers.3.self_attn.o_proj.weight change rate: 0.0005092620849609375
# model.layers.3.mlp.gate_proj.weight change rate: 0.0005024996935389936
# model.layers.3.mlp.up_proj.weight change rate: 0.0005011125467717648
# model.layers.3.mlp.down_proj.weight change rate: 0.0008281361078843474
# model.layers.4.self_attn.q_proj.weight change rate: 0.00074005126953125
# model.layers.4.self_attn.k_proj.weight change rate: 0.000518798828125
# model.layers.4.self_attn.v_proj.weight change rate: 0.000823974609375
# model.layers.4.self_attn.o_proj.weight change rate: 0.0008230209350585938
# model.layers.4.mlp.gate_proj.weight change rate: 0.0006932345568202436
# model.layers.4.mlp.up_proj.weight change rate: 0.0005045804427936673
# model.layers.4.mlp.down_proj.weight change rate: 0.0005031932378187776
# model.layers.5.self_attn.q_proj.weight change rate: 0.0007505416870117188
# model.layers.5.self_attn.k_proj.weight change rate: 0.000579833984375
# model.layers.5.self_attn.v_proj.weight change rate: 0.00075531005859375
# model.layers.5.self_attn.o_proj.weight change rate: 0.0005083084106445312
# model.layers.5.mlp.gate_proj.weight change rate: 0.0005018060910515487
# model.layers.5.mlp.up_proj.weight change rate: 0.000502846494782716
# model.layers.5.mlp.down_proj.weight change rate: 0.000502846494782716
# model.layers.6.self_attn.q_proj.weight change rate: 0.0008363723754882812
# model.layers.6.self_attn.k_proj.weight change rate: 0.00052642822265625
# model.layers.6.self_attn.v_proj.weight change rate: 0.0005340576171875
# model.layers.6.self_attn.o_proj.weight change rate: 0.0005331039428710938
# model.layers.6.mlp.gate_proj.weight change rate: 0.0005056207883171737
# model.layers.6.mlp.up_proj.weight change rate: 0.0008541454444639385
# model.layers.6.mlp.down_proj.weight change rate: 0.0008388866554014385
# model.layers.7.self_attn.q_proj.weight change rate: 0.0005521774291992188
# model.layers.7.self_attn.k_proj.weight change rate: 0.0008087158203125
# model.layers.7.self_attn.v_proj.weight change rate: 0.00067138671875
# model.layers.7.self_attn.o_proj.weight change rate: 0.0008106231689453125
# model.layers.7.mlp.gate_proj.weight change rate: 0.0007501082145608962
# model.layers.7.mlp.up_proj.weight change rate: 0.0005049272440373898
# model.layers.7.mlp.down_proj.weight change rate: 0.0008600408909842372
# model.layers.8.self_attn.q_proj.weight change rate: 0.0005407333374023438
# model.layers.8.self_attn.k_proj.weight change rate: 0.000518798828125
# model.layers.8.self_attn.v_proj.weight change rate: 0.00052642822265625
# model.layers.8.self_attn.o_proj.weight change rate: 0.0007419586181640625
# model.layers.8.mlp.gate_proj.weight change rate: 0.0005049272440373898
# model.layers.8.mlp.up_proj.weight change rate: 0.000506661192048341
# model.layers.8.mlp.down_proj.weight change rate: 0.0005042336415499449
# model.layers.9.self_attn.q_proj.weight change rate: 0.0005340576171875
# model.layers.9.self_attn.k_proj.weight change rate: 0.0005340576171875
# model.layers.9.self_attn.v_proj.weight change rate: 0.000762939453125
# model.layers.9.self_attn.o_proj.weight change rate: 0.0007524490356445312
# model.layers.9.mlp.gate_proj.weight change rate: 0.0007109208963811398
# model.layers.9.mlp.up_proj.weight change rate: 0.0008395801996812224
# model.layers.9.mlp.down_proj.weight change rate: 0.0005056207883171737
# model.layers.10.self_attn.q_proj.weight change rate: 0.0005474090576171875
# model.layers.10.self_attn.k_proj.weight change rate: 0.00079345703125
# model.layers.10.self_attn.v_proj.weight change rate: 0.00080108642578125
# model.layers.10.self_attn.o_proj.weight change rate: 0.0005178451538085938
# model.layers.10.mlp.gate_proj.weight change rate: 0.0005056207883171737
# model.layers.10.mlp.up_proj.weight change rate: 0.0005070079350844026
# model.layers.10.mlp.down_proj.weight change rate: 0.0005083951400592923
# model.layers.11.self_attn.q_proj.weight change rate: 0.00080108642578125
# model.layers.11.self_attn.k_proj.weight change rate: 0.00067138671875
# model.layers.11.self_attn.v_proj.weight change rate: 0.00087738037109375
# model.layers.11.self_attn.o_proj.weight change rate: 0.0007791519165039062
# model.layers.11.mlp.gate_proj.weight change rate: 0.000506661192048341
# model.layers.11.mlp.up_proj.weight change rate: 0.0007077997433952987
# model.layers.11.mlp.down_proj.weight change rate: 0.0005038868403062224
# model.layers.12.self_attn.q_proj.weight change rate: 0.0007314682006835938
# model.layers.12.self_attn.k_proj.weight change rate: 0.00067901611328125
# model.layers.12.self_attn.v_proj.weight change rate: 0.00091552734375
# model.layers.12.self_attn.o_proj.weight change rate: 0.0005168914794921875
# model.layers.12.mlp.gate_proj.weight change rate: 0.0007799321901984513
# model.layers.12.mlp.up_proj.weight change rate: 0.0008787675760686398
# model.layers.12.mlp.down_proj.weight change rate: 0.0007771578966639936
# model.layers.13.self_attn.q_proj.weight change rate: 0.000530242919921875
# model.layers.13.self_attn.k_proj.weight change rate: 0.00074005126953125
# model.layers.13.self_attn.v_proj.weight change rate: 0.00049591064453125
# model.layers.13.self_attn.o_proj.weight change rate: 0.000507354736328125
# model.layers.13.mlp.gate_proj.weight change rate: 0.0005090886843390763
# model.layers.13.mlp.up_proj.weight change rate: 0.0005063143908046186
# model.layers.13.mlp.down_proj.weight change rate: 0.0005045804427936673
# model.layers.14.self_attn.q_proj.weight change rate: 0.0005407333374023438
# model.layers.14.self_attn.k_proj.weight change rate: 0.0005645751953125
# model.layers.14.self_attn.v_proj.weight change rate: 0.00081634521484375
# model.layers.14.self_attn.o_proj.weight change rate: 0.0005121231079101562
# model.layers.14.mlp.gate_proj.weight change rate: 0.0008017800282686949
# model.layers.14.mlp.up_proj.weight change rate: 0.0007768110954202712
# model.layers.14.mlp.down_proj.weight change rate: 0.0008121837745420635
# model.layers.15.self_attn.q_proj.weight change rate: 0.0008401870727539062
# model.layers.15.self_attn.k_proj.weight change rate: 0.000579833984375
# model.layers.15.self_attn.v_proj.weight change rate: 0.000518798828125
# model.layers.15.self_attn.o_proj.weight change rate: 0.0005130767822265625
# model.layers.15.mlp.gate_proj.weight change rate: 0.0008617748389951885
# model.layers.15.mlp.up_proj.weight change rate: 0.0005059675895608962
# model.layers.15.mlp.down_proj.weight change rate: 0.0007421320187859237
# model.layers.16.self_attn.q_proj.weight change rate: 0.0005397796630859375
# model.layers.16.self_attn.k_proj.weight change rate: 0.000518798828125
# model.layers.16.self_attn.v_proj.weight change rate: 0.0008392333984375
# model.layers.16.self_attn.o_proj.weight change rate: 0.000507354736328125
# model.layers.16.mlp.gate_proj.weight change rate: 0.0005097822868265212
# model.layers.16.mlp.up_proj.weight change rate: 0.0005049272440373898
# model.layers.16.mlp.down_proj.weight change rate: 0.0007272200309671462
# model.layers.17.self_attn.q_proj.weight change rate: 0.0005283355712890625
# model.layers.17.self_attn.k_proj.weight change rate: 0.00054168701171875
# model.layers.17.self_attn.v_proj.weight change rate: 0.00066375732421875
# model.layers.17.self_attn.o_proj.weight change rate: 0.0005102157592773438
# model.layers.17.mlp.gate_proj.weight change rate: 0.000502846494782716
# model.layers.17.mlp.up_proj.weight change rate: 0.0005045804427936673
# model.layers.17.mlp.down_proj.weight change rate: 0.0007234053337015212
# model.layers.18.self_attn.q_proj.weight change rate: 0.0008058547973632812
# model.layers.18.self_attn.k_proj.weight change rate: 0.000518798828125
# model.layers.18.self_attn.v_proj.weight change rate: 0.00079345703125
# model.layers.18.self_attn.o_proj.weight change rate: 0.0007925033569335938
# model.layers.18.mlp.gate_proj.weight change rate: 0.000849983945954591
# model.layers.18.mlp.up_proj.weight change rate: 0.0007383173215202987
# model.layers.18.mlp.down_proj.weight change rate: 0.0007150823366828263
# model.layers.19.self_attn.q_proj.weight change rate: 0.0007867813110351562
# model.layers.19.self_attn.k_proj.weight change rate: 0.0007476806640625
# model.layers.19.self_attn.v_proj.weight change rate: 0.0007171630859375
# model.layers.19.self_attn.o_proj.weight change rate: 0.0005283355712890625
# model.layers.19.mlp.gate_proj.weight change rate: 0.0005038868403062224
# model.layers.19.mlp.up_proj.weight change rate: 0.0007303411257453263
# model.layers.19.mlp.down_proj.weight change rate: 0.0007157759391702712
# model.layers.20.self_attn.q_proj.weight change rate: 0.0007486343383789062
# model.layers.20.self_attn.k_proj.weight change rate: 0.0005340576171875
# model.layers.20.self_attn.v_proj.weight change rate: 0.0005035400390625
# model.layers.20.self_attn.o_proj.weight change rate: 0.0007009506225585938
# model.layers.20.mlp.gate_proj.weight change rate: 0.000820159912109375
# model.layers.20.mlp.up_proj.weight change rate: 0.0008444353006780148
# model.layers.20.mlp.down_proj.weight change rate: 0.0005035400390625
# model.layers.21.self_attn.q_proj.weight change rate: 0.0005369186401367188
# model.layers.21.self_attn.k_proj.weight change rate: 0.000732421875
# model.layers.21.self_attn.v_proj.weight change rate: 0.0005035400390625
# model.layers.21.self_attn.o_proj.weight change rate: 0.0007801055908203125
# model.layers.21.mlp.gate_proj.weight change rate: 0.000781319395173341
# model.layers.21.mlp.up_proj.weight change rate: 0.0007272200309671462
# model.layers.21.mlp.down_proj.weight change rate: 0.000769875303376466
# v_step_train_loss 0.1570962536570735

# %%
ppl_eval_score = eval_ppl_naive(dequantized_model, eval_data).item()
print("wikitext2 ppl (naive)", ppl_eval_score)
# Out:
#   0%|          | 0/334 [00:00<?, ?it/s]
# wikitext2 ppl (naive) 12.60940170288086
